# %%
import pandas as pd


pd.read_parquet("../artifacts/featuress/train_feats.parquet")
# Out:
#                                  z  z_err    ebv  target  \
# object_id
# Dornhoth_fervain_onodrim  3.052242    NaN  0.110       0
# Dornhoth_galadh_ylf       0.424386    NaN  0.058       0
# Elrim_melethril_thul      0.484241    NaN  0.577       0
# Ithil_tobas_rodwen        0.685241    NaN  0.012       0
# Mirion_adar_Druadan       0.414756    NaN  0.058       0
# ...                            ...    ...    ...     ...
# tinnu_gellui_tathar       0.884560    NaN  0.042       0
# uir_heleg_corf            0.973703    NaN  0.042       0
# uir_rhosc_law             0.153008    NaN  0.024       0
# uruk_in_pess              1.151943    NaN  0.019       0
# ylf_alph_mindon           0.568992    NaN  0.034       0
#
#                           BazinFit_Amplitude_g  BazinFit_Amplitude_i  \
# object_id
# Dornhoth_fervain_onodrim              1.477193             15.050892
# Dornhoth_galadh_ylf                   1.219824              1.667286
# ...
